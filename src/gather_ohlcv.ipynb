# %% [markdown]
# # Collecting downloaded files and Save as a parquet file

# %%
import polars as pl
import os

def is_not_valid(f: str) -> bool:
    return not f.endswith('.csv') or '-' in f 
    # or '.P,' not in f

# %%
def convert_k(val):
    if isinstance(val, str) and val.endswith('K'):
        return float(val[:-1]) * 1000
    return float(val)

def collect(folder):
    ohlcv = []
    for f in os.listdir(folder):
        if is_not_valid(f):
            continue

        path = os.path.join(folder, f)
        try:
            df = pl.read_csv(
                path, 
                schema_overrides={c: pl.Float64 for c in ['open', 'high', 'low', 'close', 'Volume']},
                null_values=["∅"], ignore_errors=True
            )
        except Exception as e:
            print(f"❌ Skipping file {f} due to read error: {e}")
            continue
        
        if 'date' in df.columns: # ['date', 'time', 'open', 'high', 'low', 'close', 'vol']
            df = df.with_columns(
                (pl.col("date") + " " + pl.col("time")).str.strptime(pl.Datetime, format="%Y-%m-%d %H:%M").alias("datetime")
            )
            df = df.with_columns(
                (pl.col("datetime").cast(pl.Int64))# nanoseconds → seconds
                .alias("time")
            )
            df = df.select(["time", "open", "high", "low", "close", pl.col("vol").alias("Volume")])
            if df.schema.get('Volume') == pl.String:
                df = df.with_columns(
                    pl.col("Volume")
                    .str.replace_all(r"([0-9.]+)K", r"${1}000")
                    .str.replace_all(r"([0-9.]+)M", r"${1}000000")
                    .str.strip_chars()
                    .cast(pl.Float64)
                    .alias("Volume")
                )
        if df.schema.get('time') != pl.Int64:
            continue

        f = f.replace(', 1D.csv', ', 1440.csv')  # Fix for some files with space
        df = df.with_columns([
            pl.lit(f.split('_')[-2].lower()).alias('Exchange'),
            pl.lit(f.split('_')[-1].split(',')[0]).alias('Pair'),
            pl.lit(f.split(',')[-1].split('.')[0].strip().split()[0]).cast(pl.Int16).alias('Interval'),
            pl.lit(f).alias('FileName'),
        ])
 
        
        ohlcv.append(df)
    print(f"✅ Processed {len(ohlcv)} files from {folder}")
    return ohlcv

# %%
ohlcv_dumdum = collect('../../dumdum')
ohlcv_root = collect('../../')
ohlcv_root = []
df_all = pl.concat(ohlcv_dumdum + ohlcv_root, how="vertical").unique()
# Out:
# ✅ Processed 8379 files from ../../dumdum
# ✅ Processed 1847 files from ../../

# %%
print(
    f"✅ Total {len(df_all)} unique rows from all files. Columns: {df_all.columns}"
)
df_all.schema
# Out:
# ✅ Total 95871172 unique rows from all files. Columns: ['time', 'open', 'high', 'low', 'close', 'Volume', 'Exchange', 'Pair', 'Interval', 'FileName']
# Schema([('time', Int64),
#         ('open', Float64),
#         ('high', Float64),
#         ('low', Float64),
#         ('close', Float64),
#         ('Volume', Float64),
#         ('Exchange', String),
#         ('Pair', String),
#         ('Interval', Int16),
#         ('FileName', String)])

# %%
# 병합 및 중복 제거
prev = pl.read_parquet('../../tradingview_ohlcv_old.parquet').with_columns(
    (pl.col("time").cast(pl.Int64) // 1_000_000_000).alias("time"),
    (pl.lit(9999).cast(pl.Int16)).alias('Interval'),
    (pl.lit('first-version')).alias('FileName'),
)
print(f"✅ Loaded previous data with {prev.shape[0]} rows")
df_all = pl.concat([prev, df_all], how="vertical").unique()



df_all = df_all.with_columns(
    (pl.col("Pair").str.contains(r"\.(P|PS)$")).alias("Perpetual")
)
df_all = df_all.filter((pl.col("time").is_not_null()) & (pl.col('Volume').is_not_null()) & (pl.col('close').is_not_null()))


df_all = (
    df_all.sort(["FileName"])  # 우선 C 오름차순 정렬
      .unique(subset=["time",'Exchange', 'Pair', 'Interval'], keep="first")  # A, B 기준으로 유니크하게, C가 작은 row 유지
) #  "open", 'high', 'low', 'Volume',  

df_all
# Out:
# ✅ Loaded previous data with 12613878 rows
# shape: (61_703_595, 11)
# ┌────────────┬────────────┬───────────┬─────────┬───┬───────────┬──────────┬───────────┬───────────┐
# │ time       ┆ open       ┆ high      ┆ low     ┆ … ┆ Pair      ┆ Interval ┆ FileName  ┆ Perpetual │
# │ ---        ┆ ---        ┆ ---       ┆ ---     ┆   ┆ ---       ┆ ---      ┆ ---       ┆ ---       │
# │ i64        ┆ f64        ┆ f64       ┆ f64     ┆   ┆ str       ┆ i16      ┆ str       ┆ bool      │
# ╞════════════╪════════════╪═══════════╪═════════╪═══╪═══════════╪══════════╪═══════════╪═══════════╡
# │ 1689256800 ┆ 30673.4    ┆ 30697.7   ┆ 30474.1 ┆ … ┆ BTCUSDC.P ┆ 60       ┆ 20250705_ ┆ true      │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ 213609_OK ┆           │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ X_BTCUSDC ┆           │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ .P,…      ┆           │
# │ 1740863700 ┆ 604.84     ┆ 605.33    ┆ 604.39  ┆ … ┆ BNBUSDT   ┆ 15       ┆ 20250708_ ┆ false     │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ 235845_BI ┆           │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ TMART_BNB ┆           │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ USD…      ┆           │
# │ 1751923800 ┆ 2.8331     ┆ 2.85      ┆ 2.8323  ┆ … ┆ SUIUSDT   ┆ 15       ┆ 20250708_ ┆ false     │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ 221228_BI ┆           │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ NANCE_SUI ┆           │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ USD…      ┆           │
# │ 1701118800 ┆ 13.95      ┆ 14.128    ┆ 13.935  ┆ … ┆ LINKUSDT. ┆ 60       ┆ 20250706_ ┆ true      │
# │            ┆            ┆           ┆         ┆   ┆ P         ┆          ┆ 043745_PH ┆           │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ EMEX_LINK ┆           │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ USD…      ┆           │
# │ 1581379200 ┆ 222.993539 ┆ 239.15442 ┆ 218.2   ┆ … ┆ ETHUSDT   ┆ 1440     ┆ 20250708_ ┆ false     │
# │            ┆            ┆ 9         ┆         ┆   ┆           ┆          ┆ 141527_PO ┆           │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ LONIEX_ET ┆           │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ HUS…      ┆           │
# │ …          ┆ …          ┆ …         ┆ …       ┆ … ┆ …         ┆ …        ┆ …         ┆ …         │
# │ 1679248800 ┆ 1811.84    ┆ 1824.93   ┆ 1808.46 ┆ … ┆ ETHUSD    ┆ 9999     ┆ first-ver ┆ false     │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ sion      ┆           │
# │ 1701597600 ┆ 39472.6    ┆ 39556.4   ┆ 39428.1 ┆ … ┆ BTCUSD.P  ┆ 60       ┆ 20250705_ ┆ true      │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ 215033_CR ┆           │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ YPTOCOM_B ┆           │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ TCU…      ┆           │
# │ 1735974000 ┆ 7.781      ┆ 7.795     ┆ 7.745   ┆ … ┆ DOTUSDT.P ┆ 60       ┆ 20250706_ ┆ true      │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ 021102_CO ┆           │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ INW_DOTUS ┆           │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ DT.…      ┆           │
# │ 1733330400 ┆ 3779.97    ┆ 3781.16   ┆ 3738.8  ┆ … ┆ ETHUSDT   ┆ 20       ┆ PHEMEX_ET ┆ false     │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ HUSDT,    ┆           │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ 20.csv    ┆           │
# │ 1715270400 ┆ 3013.7     ┆ 3019.5    ┆ 3003.6  ┆ … ┆ ETHUSDC   ┆ 9999     ┆ first-ver ┆ false     │
# │            ┆            ┆           ┆         ┆   ┆           ┆          ┆ sion      ┆           │
# └────────────┴────────────┴───────────┴─────────┴───┴───────────┴──────────┴───────────┴───────────┘

# %%
# 1. 중복되는 조합의 키 만들기
df = df_all.with_columns([
    (pl.col("time").cast(pl.String) + "|" + pl.col("Exchange") + "|" + pl.col("Pair")+ "|" + pl.col("Interval").cast(pl.String)).alias("key")
])

# 2. 중복 key를 가진 row만 필터링
duplicated_keys = (
    df.group_by("key")
    .agg(pl.len().alias("cnt"))
    .filter(pl.col("cnt") > 1)
    .select("key")
)

df_dupes = df.join(duplicated_keys, on="key", how="inner").drop("key").sort(['time', 'Exchange', 'Pair'])
df_dupes
# Out:
# shape: (0, 11)
# ┌──────┬──────┬──────┬─────┬───┬──────┬──────────┬──────────┬───────────┐
# │ time ┆ open ┆ high ┆ low ┆ … ┆ Pair ┆ Interval ┆ FileName ┆ Perpetual │
# │ ---  ┆ ---  ┆ ---  ┆ --- ┆   ┆ ---  ┆ ---      ┆ ---      ┆ ---       │
# │ i64  ┆ f64  ┆ f64  ┆ f64 ┆   ┆ str  ┆ i16      ┆ str      ┆ bool      │
# ╞══════╪══════╪══════╪═════╪═══╪══════╪══════════╪══════════╪═══════════╡
# └──────┴──────┴──────┴─────┴───┴──────┴──────────┴──────────┴───────────┘

# %%
df_all.write_parquet('../tradingview_ohlcv.parquet')

# %% [markdown]
# # Statistical Description

# %%
import polars as pl

df_all = pl.read_parquet('../tradingview_ohlcv.parquet')

# %%
df_spot = df_all.filter(~pl.col("Perpetual")).to_pandas()
df_perp = df_all.filter(pl.col("Perpetual")).to_pandas()

# %%
import pandas as pd

df_spot['time'] = pd.to_datetime(df_spot['time'], unit='s', errors='coerce')
df_perp['time'] = pd.to_datetime(df_perp['time'], unit='s', errors='coerce')
print(df_spot.shape, df_perp.shape)
print(df_spot.columns)


df_spot_binance = df_spot[df_spot['Exchange'] == 'binance'].copy()
df_spot_binance.value_counts('Interval', dropna=False).sort_index()
# Out:
# (48637216, 11) (13066379, 11)
# Index(['time', 'open', 'high', 'low', 'close', 'Volume', 'Exchange', 'Pair',
#        'Interval', 'FileName', 'Perpetual'],
#       dtype='object')
# Interval
# 1        301156
# 15      1203184
# 20       410008
# 30        27268
# 60       400692
# 1440     108722
# 9999     686987
# Name: count, dtype: int64

# %%
df_spot.describe(include='all')
# Out:
#                                  time          open          high  \
# count                        48603439  4.863722e+07  4.863722e+07
# unique                            NaN           NaN           NaN
# top                               NaN           NaN           NaN
# freq                              NaN           NaN           NaN
# mean    2024-10-10 09:41:21.078161664  5.052994e+05  5.062661e+05
# min               2011-08-18 00:00:00  0.000000e+00  1.500000e-07
# 25%               2024-09-07 07:00:00  2.251600e+00  2.257440e+00
# 50%               2025-02-02 10:15:00  1.571098e+02  1.577955e+02
# 75%               2025-05-07 17:00:00  3.366600e+03  3.378400e+03
# max               2025-07-10 03:59:00  1.624540e+08  1.634600e+08
# std                               NaN  7.663662e+06  7.676647e+06
#
#                  low         close        Volume  Exchange      Pair  \
# count   4.863722e+07  4.863722e+07  4.804751e+07  48637216  48637216
# unique           NaN           NaN           NaN        39       115
# top              NaN           NaN           NaN   binance   BTCUSDT
# freq             NaN           NaN           NaN   3138017   3503107
# mean    5.043206e+05  5.053146e+05  2.653273e+09       NaN       NaN
# min     0.000000e+00  0.000000e+00  0.000000e+00       NaN       NaN
# 25%     2.245600e+00  2.251600e+00  5.247568e+00       NaN       NaN
# 50%     1.565200e+02  1.571000e+02  3.378236e+02       NaN       NaN
# 75%     3.354200e+03  3.366570e+03  1.263204e+04       NaN       NaN
# max     1.618240e+08  1.624700e+08  2.542703e+14       NaN       NaN
# std     7.650565e+06  7.663826e+06  2.540473e+11       NaN       NaN
#
#             Interval       FileName Perpetual
# count   4.863722e+07       48637216  48637216
# unique           NaN           4654         1
# top              NaN  first-version     False
# freq             NaN       10335321  48637216
# mean    2.184988e+03            NaN       NaN
# min     1.000000e+00            NaN       NaN
# 25%     1.500000e+01            NaN       NaN
# 50%     2.000000e+01            NaN       NaN
# 75%     6.000000e+01            NaN       NaN
# max     9.999000e+03            NaN       NaN
# std     4.066370e+03            NaN       NaN

# %%
df_perp.describe(include='all')
# Out:
#                                  time          open          high  \
# count                        13066379  1.306638e+07  1.306638e+07
# unique                            NaN           NaN           NaN
# top                               NaN           NaN           NaN
# freq                              NaN           NaN           NaN
# mean    2024-06-09 08:07:13.740308992  6.970964e+03  6.991591e+03
# min               2019-11-18 00:00:00  0.000000e+00  0.000000e+00
# 25%               2023-11-12 06:00:00  6.337000e-01  6.380000e-01
# 50%               2024-07-20 05:00:00  1.146800e+01  1.155200e+01
# 75%               2025-02-03 05:00:00  2.455000e+02  2.468500e+02
# max               2025-07-10 03:40:00  1.120107e+05  1.120872e+05
# std                               NaN  2.218637e+04  2.224760e+04
#
#                  low         close        Volume  Exchange       Pair  \
# count   1.306638e+07  1.306638e+07  1.306570e+07  13066379   13066379
# unique           NaN           NaN           NaN        27        104
# top              NaN           NaN           NaN     bingx  BTCUSDT.P
# freq             NaN           NaN           NaN   1457118     654828
# mean    6.950086e+03  6.971334e+03  6.954582e+09       NaN        NaN
# min     0.000000e+00  0.000000e+00  0.000000e+00       NaN        NaN
# 25%     6.300000e-01  6.337000e-01  4.837000e+03       NaN        NaN
# 50%     1.138900e+01  1.146900e+01  7.806785e+04       NaN        NaN
# 75%     2.443228e+02  2.455000e+02  1.215332e+06       NaN        NaN
# max     1.117870e+05  1.120107e+05  2.312292e+15       NaN        NaN
# std     2.212484e+04  2.218736e+04  1.247320e+12       NaN        NaN
#
#             Interval       FileName Perpetual
# count   1.306638e+07       13066379  13066379
# unique           NaN           1605         1
# top              NaN  first-version      True
# freq             NaN         178659  13066379
# mean    2.063235e+02            NaN       NaN
# min     1.000000e+00            NaN       NaN
# 25%     6.000000e+01            NaN       NaN
# 50%     6.000000e+01            NaN       NaN
# 75%     6.000000e+01            NaN       NaN
# max     9.999000e+03            NaN       NaN
# std     1.160998e+03            NaN       NaN

# %%
df_spot.time.value_counts().to_frame().sort_index()
# Out:
#                      count
# time
# 2011-08-18 00:00:00      1
# 2011-08-19 00:00:00      1
# 2011-08-20 00:00:00      1
# 2011-08-21 00:00:00      1
# 2011-08-22 00:00:00      1
# ...                    ...
# 2025-07-10 03:55:00      7
# 2025-07-10 03:56:00      7
# 2025-07-10 03:57:00      4
# 2025-07-10 03:58:00      4
# 2025-07-10 03:59:00      1
#
# [714056 rows x 1 columns]

# %%
df_spot.Exchange.value_counts().to_frame().sort_index()
# Out:
#               count
# Exchange
# binance     3138017
# binanceus   1896551
# bingx           281
# bitfinex     850502
# bitflyer     147788
# bitget      1744087
# bithumb      834422
# bitmart     1710678
# bitmex       373334
# bitrue      1427238
# bitso       1246711
# bitstamp    1394353
# bittrex     1602014
# bitvavo      374896
# blofin       509253
# bybit       2073552
# capitalcom   961788
# coinbase    2570812
# coinex      1638469
# coinw        865101
# cryptocom   1815564
# delta        159425
# deribit      631060
# gateio       984669
# gemini       600110
# htx         1227182
# huobi           567
# kcex         602299
# kraken      2282414
# kucoin      1858436
# mexc        1919682
# okcoin       248032
# okx         2211158
# phemex      1765090
# poloniex    1915158
# pyth         589356
# upbit       1085973
# weex        1397890
# whitebit    1983304

# %%
df_spot.Pair.value_counts().to_frame().head(20)
# Out:
#             count
# Pair
# BTCUSDT   3503107
# ETHUSDT   3305000
# XRPUSDT   3223357
# ETHUSDC   2418588
# BTCUSDC   2330853
# SOLUSDT   2256926
# ETHUSD    1955866
# XRPUSDC   1815078
# BTCUSD    1696439
# XRPUSD    1634181
# SUIUSDT   1561330
# SOLUSDC   1452741
# SOLUSD    1291096
# WBTCUSDT  1079603
# BTCDAI     729193
# ETHDAI     714718
# SUIUSD     671859
# SUIUSDC    646669
# WBTCUSD    555666
# DOGEUSDT   508911

# %%
df_spot.Pair.value_counts().to_frame().tail(20)
# Out:
#               count
# Pair
# MATICUSDC     22731
# 1000BONKUSDT  22062
# BNBKRW        21704
# USTUSDT       20118
# SOLGUSD       10957
# DOGEGUSD       8942
# LTCGUSD        8918
# PEPEGUSD       8908
# SHIBGUSD       8649
# LINKGUSD       8392
# AVAXGUSD       7368
# BCHGUSD        7071
# UNIGUSD        6662
# AAVEGUSD       6180
# MATICGUSD      5155
# OPGUSD         3409
# DOTGUSD        2331
# USTUSDC        2204
# TRUMPGUSD      1129
# USCUSD          673

# %%
df_perp.time.value_counts().to_frame().sort_index()
# Out:
#                      count
# time
# 2019-11-18 00:00:00      1
# 2019-11-19 00:00:00      1
# 2019-11-20 00:00:00      1
# 2019-11-21 00:00:00      1
# 2019-11-22 00:00:00      1
# ...                    ...
# 2025-07-10 03:36:00      1
# 2025-07-10 03:37:00      1
# 2025-07-10 03:38:00      1
# 2025-07-10 03:39:00      1
# 2025-07-10 03:40:00      1
#
# [99938 rows x 1 columns]

# %%
df_perp.Exchange.value_counts().to_frame().sort_index()
# Out:
#              count
# Exchange
# binance     980361
# bingx      1457118
# bitget      798518
# bitmart     477020
# bitmex      687818
# blofin      429142
# bybit       849066
# coinbase    278712
# coinw       128711
# cryptocom   385972
# deepcoin    393169
# delta       452853
# deltain     208604
# deribit     308250
# gateio      457518
# gemini      114579
# htx         607594
# kcex        289233
# kraken       87771
# lbank       412888
# mexc        617632
# okx         781951
# phemex      435977
# pionex      390747
# weex        290305
# whitebit    318376
# zoomex      426494

# %%
df_perp.Pair.value_counts().to_frame().head(20)
# Out:
#              count
# Pair
# BTCUSDT.P   654828
# DOTUSDT.P   444385
# ADAUSDT.P   438174
# ETHUSDT.P   428893
# DOGEUSDT.P  424611
# AVAXUSDT.P  424455
# SOLUSDT.P   424132
# BCHUSDT.P   421669
# XRPUSDT.P   419966
# LTCUSDT.P   417949
# OPUSDT.P    416746
# LINKUSDT.P  414815
# BNBUSDT.P   398022
# UNIUSDT.P   383522
# AAVEUSDT.P  371101
# SUIUSDT.P   352446
# XLMUSDT.P   342015
# BTCUSD.P    312292
# ETHUSD.P    291667
# SHIBUSDT.P  238532

# %%
df_perp.Pair.value_counts().to_frame().tail(20)
# Out:
#                      count
# Pair
# BTCGUSD.P            15826
# ETHGUSD.P            14936
# PEPEGUSD.P           11975
# SOLGUSD.P            11293
# XRPGUSD.P             9842
# DOGEGUSD.P            9738
# AVAXGUSD.P            9037
# SHIBUSDC.P            8975
# LTCGUSD.P             8284
# TRUMPUSD.P            8079
# TRUMPOFFICIALUSDT.P   7562
# BNBGUSD.P             6661
# PEPEUSDC.P            6611
# LINKGUSD.P            4375
# BCHGUSD.P             4121
# DOTUSDT.PS            4080
# UNIGUSD.P             3096
# SHIBGUSD.P            2270
# OPGUSD.P              2012
# TRUMPGUSD.P           1113
